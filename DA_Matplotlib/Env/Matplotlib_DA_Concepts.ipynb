# %% [markdown]
# # Matplotlib Overview Lecture

# %% [markdown]
# ## Introduction
#
# Matplotlib is the "Grandfather" library of data visualization with python. It was created by John Hunter. He created it to try to replicate MatLab's (another programming language) plotting capabilities in Python. So if you happen to be familiar with matlab, matplotlib will feel natural to you
#
# it is an excellent 2D and 3D graphics library for generating scientific figures.
#
# - Generally easy to get started for simple plots
# - Support for custom labels and texts
# - Grat control of every element in a figure
# - High-quality output in many formats
# - Very customizable in general

# %% [markdown]
# #### Importing
# Import the matplotlib.pyplot module under the name plt

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# You'll also need to use this line to see plots in the notebook:

# %%
# %matplotlib inline

# %% [markdown]
# That line is only for jupyter notebooks, if you are using another editor, you'll use: plt.show() at the end of all yout plotting commands to have the figure pop up in another window

# %% [markdown]
# ## Basic Example

# %%
import numpy as np 
x = np.linspace(0, 5, 11, endpoint=True)
y = x ** 2

# %%
print(x)
print(y)
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# [ 0.    0.25  1.    2.25  4.    6.25  9.   12.25 16.   20.25 25.  ]

# %%
plt.plot(x, y, 'r')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Test')
plt.show()

# %%
# plt.subplot(nrwos, ncols, plot_number)
# ex :
plt.subplot(1, 2, 1)
plt.title('x, y')
plt.plot(x, y, 'r--')


plt.subplot(1, 2, 2)
plt.title('y, x')
plt.plot(y, x + 0.5, 'g*--')

plt.suptitle('Super Title')
# Out:
# Text(0.5, 0.98, 'Super Title')

# %% [markdown]
# ## Matplotlib Object Oriented Method
# Now that, we've seen the basics, let's break it all down with a more formal introduction of Matplotlib's Object Oriented API. This means we will instantiate figure objects and then call methods or attributes from that object

# %% [markdown]
# ### Introduction to the Object Oriented Method
# The main idea in using the mote formal OO methid is to create figure objects and then just call methods or attributes off of that object. This approach is nicer when dealing with a canvas that has multiple plots on it.
#
# To begin we create a figure instance. Then we can add axes to that figure

# %%
fig = plt.figure()

# left, bottom, width, height
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

# plot on that set of axes
axes.plot(x, y, 'b')
axes.set_xlabel('set X Label')
axes.set_ylabel('set Y Label')
axes.set_title('Set title')
# Out:
# Text(0.5, 1.0, 'Set title')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

# Larger Figure axis 1
axes1.plot(x, y, 'b--')
axes1.set_xlabel('X label_axes1')
axes1.set_ylabel('Y label_axes1')
axes1.set_title('Set Title of axes1')

# Insert Figure axis 2
axes2.plot(y, x, 'g--')
axes2.set_xlabel('X label_axes2')
axes2.set_ylabel('Y label_axes2')
axes2.set_title('Set Title of axes2')
# Out:
# Text(0.5, 1.0, 'Set Title of axes2')

# %% [markdown]
# ## subplots()
#
# The plt.subplots() objects will act as a mote automatic axis manager

# %%
fig, axes = plt.subplots()

# now use the axes object to add stuff to plot
axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# Then you can specify the number of rows and columns when creating the subplots() object

# %% [markdown]
# We can iterate through this array

# %%
fig, axes = plt.subplots()

axes.plot(x, y,'b')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
for ax in axes:
    ax.plot(x, y, 'r')
    ax.set_xlabel('X label')
    ax.set_ylabel('Y label')
    ax.set_title('title')
    
fig

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x, y)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')
    
fig
plt.tight_layout()

# %% [markdown]
# ### Figure size, aspect ratio and DPI

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and DPI keyword Arguments
#
# - Figsize is a tuple of the width and height of the figure in inches
# -  DPI is the dots-per-inch
#
# for example

# %%
fig = plt.figure(figsize=(8, 4), dpi=100)

# %%
fig, axes = plt.subplots(figsize=(12, 4))

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('plot')
# Out:
# Text(0.5, 1.0, 'plot')

# %%
fig, axes = plt.subplots(figsize=(12, 4), dpi=100)

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('plot')
# Out:
# Text(0.5, 1.0, 'plot')

# %% [markdown]
# ### Saving figures
# Matplotlib can generate high-quality outout in a number formula, including PNG, JPG, EPS, SVG, PGF, PDF

# %% [markdown]
# To save a figure to a file we can use the savefig method int the Figure class

# %%
fig.savefig("plot.png")

# %%
fig.savefig("plot.png", dpi=200)

# %% [markdown]
# ## Legends, labels and titles

# %% [markdown]
# Now that we have convered the basics of how to create a figure canvas and add axes instances to the canvas, let's look at how decorate a figure with titles, axis labels, ans legends

# %% [markdown]
# #### Figure titles
# A title can be added to each axis instance in a figure. To set the title, use the set_title method in the axes instance

# %%
ax.set_title('Set title')
# Out:
# Text(0.5, 1.0, 'Set title')

# %% [markdown]
# #### Legends
# You can use the label="label text" keyword argument when plots or other object are added to the figure, and then using the legend method without arguments to add the legend to the figure

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])

ax.plot(x, x ** 2, label="x**2")
ax.plot(x, x ** 3, label="x**3")
ax.legend(loc=2)

"""
    loc == 1 in the upper right corner
    loc == 2 in the upper left corner
    loc == 3 in the lower left corner
    loc == 4 in the lower right corner
"""
# Out:
# '\n    loc == 1 in the upper right corner\n    loc == 2 in the upper left corner\n    loc == 3 in the lower left corner\n    loc == 4 in the lower right corner\n'

# %% [markdown]
# ### Setting colors, linewidths, linetypes
#
# Matplotlib gives you a lot of options for customizing colors, linewidths, and linetypes
#
# There is the basic MATLAB like syntax (which I would suggest you) avoid using for more clairity sake

# %% [markdown]
# #### Color with the color = parameter
# We can also define colors by their names or RGB hex codes and optionally provide an alpha value using th ecolor and alpha keyboard arguments. Alpha indicates opacity

# %%
fig, ax = plt.subplots()

ax.plot(x, x + 1, color="blue", alpha=0.5) # half-transparant
ax.plot(x, x + 2, color="#8B008B")
ax.plot(x, x + 3, color="#FF8C00")

# %% [markdown]
# ### Line and Marker Styles

# %% [markdown]
# To change the line width, we can use the linewidth or lw keyword argument. The line style can be selected using the linestyle or ls keyword arguments:

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(x, x + 1, color="red", linewidth=0.25)
ax.plot(x, x + 2, color="red", linewidth=0.5)
ax.plot(x, x + 3, color="red", linewidth=1)
ax.plot(x, x + 4, color="red", linewidth=2)

# Possible linestype options '- or -. or : etc'
ax.plot(x, x + 5, color="green", lw=3, linestyle='-')
ax.plot(x, x + 6, color="green", lw=3, ls='-.')
ax.plot(x, x + 7, color="green", lw=3, ls=":")

# Custom Dash
line, = ax.plot(x, x + 8, color="black", lw=1.5)
line.set_dashes([5, 10, 15, 10]) 

# Possible marker symbol: marker = "+", "o", "*", "1", etc
ax.plot(x, x + 9, color="blue", lw=3, ls="-", marker="+")
ax.plot(x, x + 10, color="blue", lw=3, ls="--", marker="o")
ax.plot(x, x + 11, color="blue", lw=3, ls="-", marker="s")
ax.plot(x, x + 12, color="blue", lw=3, ls="--", marker="1")

# marker size and color
ax.plot(x, x + 13, color="purple", lw=1, ls="-", marker="o", markersize=2)
ax.plot(x, x + 14, color="purple", lw=1, ls="-", marker="o", markersize=4)
ax.plot(x, x + 15, color="purple", lw=1, ls="-", marker="o", markersize=8, markerfacecolor="red")
ax.plot(x, x + 16, color="purple", lw=1, ls="-", marker="s", markersize=8, markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green")

# %% [markdown]
# ### Control Over Axis Appreance
#
# in this section we will look at controlling axis sizing properties in a matplotplib figure

# %% [markdown]
# ### Plot range

# %% [markdown]
# We can configure the ranges of the axes using the set_ylim and set_xlim methods in the axis object, or axis('tight') for automatically getting "tightly fitted' axes ranges:

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x ** 2, x, x **3)
axes[0].set_title('Default axes ranges')

axes[1].plot(x, x ** 2, x, x ** 3)
axes[1].axis('tight')
axes[1].set_title("Tight axes")

axes[2].plot(x, x ** 2, x, x ** 3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("Custom axes range")
# Out:
# Text(0.5, 1.0, 'Custom axes range')

# %% [markdown]
# ### Special plot types
#
# There are many specialized plots we can create, such as barplots, histograms, scatter plots, and much more. Most of these type of plots we will actually create using seaborn, a statistical plotting library for Python. But here are a fw examples of these type of plots.

# %%
plt.scatter(x, y)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([12., 10.,  9.,  8., 10.,  7., 11.,  8.,  9., 16.]),
#  array([  2. ,  98.9, 195.8, 292.7, 389.6, 486.5, 583.4, 680.3, 777.2,
#         874.1, 971. ]),
#  <BarContainer object of 10 artists>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# Rectangular box plot
plt.boxplot(data, vert=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20dc4b0dab0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20dc4b0f160>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x20dc4b0dba0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x20dc4b0eda0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x20dc4b0ef20>,
# ...
#  'means': []}
