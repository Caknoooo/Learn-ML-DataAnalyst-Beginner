# %% [markdown]
# ## Advanced Matplotlib Concepts Lecture
# in this lecture we cover some more advanced topics which you won't usually use as often. You can also always reference the documentation for more resources

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Logaritmic Scale
#
# it's also possible to set a logaritmic scale for one or both axes. This functionallity is'n fact only one application of a more general transformation system in Matplotlib. Each of the axes scales are set seperately using set_xscale and set_yscale methos whics accept one parameter (with the value "log" in this case)

# %%
x = np.linspace(0, 5, 11, endpoint=True)
y = x ** 2

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].plot(x, x ** 2, x, np.exp(x))
axes[0].set_title('Normal Scale')

axes[1].plot(x, x ** 2, x, np.exp(x))
axes[1].set_yscale('log')
axes[1].set_title("Logarithmic scale(y)")
# Out:
# Text(0.5, 1.0, 'Logarithmic scale(y)')

# %% [markdown]
# ### Placement of ticks and custom tick labels
# We can explicitly determine where we want the axis ticks with set_xticks and set_yticks, which both take a list of values for where on the axis the ticks are to be placed. We can also use the set_xticklabels and set_yticklabels methods to provide a list of custom text label for each tick location:

# %%
fig, ax = plt.subplots(figsize=(10, 4))

ax.plot(x, x**2, x**3, lw=2)
ax.set_xticks([1, 2, 3, 4, 5])
ax.set_xticklabels([r'$\alpha$', r'$\beta$', r'$\gamma$', r'$\delta$', r'$\epsilon$'], fontsize=18)

yticks = [0, 50, 100, 150]
ax.set_yticks(yticks)
ax.set_yticklabels(["$%.1f$" % y for y in yticks], fontsize=18)
# Out:
# [Text(0, 0, '$0.0$'),
#  Text(0, 50, '$50.0$'),
#  Text(0, 100, '$100.0$'),
#  Text(0, 150, '$150.0$')]

# %%
fig, ax = plt.subplots(1, 1)

ax.plot(x, x ** 2, x, np.exp(x))
ax.set_title('Scientific Notation')

ax.set_yticks([0, 50, 100, 150])


from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1, 1))
ax.yaxis.set_major_formatter(formatter)

# %% [markdown]
# #### Axis number and axis label spacing

# %%
# distance between x and y axis and the numbers on the axes
import matplotlib

matplotlib.rcParams['xtick.major.pad'] = 5
matplotlib.rcParams['ytick.major.pad'] = 5

fig, ax = plt.subplots(1, 1)

ax.plot(x, x**2, x, np.exp(x))
ax.set_yticks([0, 50, 100, 150])

ax.set_title("Label and axis spacing")

# Padding between axis label and axis numbers
ax.xaxis.labelpad = 5
ax.yaxis.labelpad = 5

ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')
