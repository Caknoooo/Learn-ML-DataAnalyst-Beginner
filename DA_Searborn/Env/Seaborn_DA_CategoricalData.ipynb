# %% [markdown]
# ## Categorical Data Plots
#
# Now let's discuss using seaborn to plot categorical data! There are a few main plot types for this:
#
# - Factorplot
# - Boxplot
# - Violinplot
# - Stripplot
# - Swarmplot
# - Barplot
# - Countplot

# %%
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Barplot and Countplit
# These very similar plots allow you to get aggregate data off a categorical feature in your data. Barplot is ad general plot that allows you yo aggregate the categorical data based off same function, by default the mean

# %%
sns.barplot(x='sex', y = 'total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='tip', y = 'total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=tips, estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### Countplot
# This is essentially the same as barplot except the estimator is explicitly counting the number of occurrences. Which is why we only pass the x value:

# %%
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ### Boxplot and Violinplot
# boxplots and violinplots are use to show the distribution of categorical data. A box plot (or box-and-whisker plot) shows the distribution of quantitive data in a way that facilitates comparisons between variables or across levels of a categorical dvariable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are detemined to be "outliers" using a method that is a function of the inter-quartile range.

# %%
sns.boxplot(x='day', y='total_bill', data=tips, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips, palette='rainbow', orient='h')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='day', y='total_bill', hue='smoker', data=tips, palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Violinplot
# A violin plot plays a similar role as a box and whisker plot. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation of the underlying distribution.

# %%
sns.violinplot(x='day', y='total_bill', data=tips, palette='rainbow')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
